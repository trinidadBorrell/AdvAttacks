# %%
import utils
import torch
from torchvision import models, transforms
import torch.nn.functional as F
import torch.nn as nn
import json
import gzip

from utils import get_coarse_arrays, eliminate_elements_torch
from utils import ensamble_attack_coarse_classes_sum_full_v2

from PIL import Image, ImageEnhance
import os
from tqdm import tqdm

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#with open(os.path.join(res_path, 'results.json'), 'r') as json_file:
#    loaded_results = json.load(json_file)

# %%
classes = utils.get_imagenet_classes()
default_weights = utils.get_default_weights()
models_classif = utils.get_class_model_names()
models_ = utils.get_models_ensamble(models)
labels, index = get_coarse_arrays()

# %%
def generate_list(length, specified_positions, weights):
    weights = weights[0]
    output_list = [0] * length
    for i, pos in enumerate(specified_positions):
        output_list[pos] = weights[i]
    return output_list

def extract_and_normalize(original_probs, positions):
    # Extract values at specified positions
    extracted_values = original_probs[:, positions]
    # Sum of extracted values
    sum_values = torch.sum(extracted_values)
    # Normalize extracted values
    weights = extracted_values / sum_values
    return weights.tolist()

def extract_values(original_list, specified_indexes):
    # Use list comprehension to filter out values not corresponding to specified indexes
    extracted_values = [original_list[i] for i in range(len(original_list)) if i not in specified_indexes]
    return extracted_values

# %%
def randomize_phase_torch(image_tensor):
    # Convert torch tensor to NumPy array
    image_np = image_tensor.detach().numpy()

    # Separate color channels
    red_channel = image_np[:, 0, :, :]
    green_channel = image_np[:, 1, :, :]
    blue_channel = image_np[:, 2, :, :]

    # Compute FFT for each color channel
    red_fft = np.fft.fft2(red_channel, axes=(-2, -1))
    green_fft = np.fft.fft2(green_channel, axes=(-2, -1))
    blue_fft = np.fft.fft2(blue_channel, axes=(-2, -1))

    # Randomize phases for each color channel
    red_phases = np.angle(red_fft)
    green_phases = np.angle(green_fft)
    blue_phases = np.angle(blue_fft)

    randomized_g_phases = np.exp(1j * np.random.uniform(-np.pi, np.pi, red_phases.shape))
    randomized_green_phases = np.exp(1j * np.random.uniform(-np.pi, np.pi, green_phases.shape))
    randomized_blue_phases = np.exp(1j * np.random.uniform(-np.pi, np.pi, blue_phases.shape))

    # Combine magnitudes with randomized phases for each color channel
    randomized_red_fft = np.abs(red_fft) * randomized_g_phases
    randomized_green_fft = np.abs(green_fft) * randomized_g_phases
    randomized_blue_fft = np.abs(blue_fft) * randomized_g_phases

    # Compute the inverse FFT for each color channel
    randomized_red_channel = np.fft.ifft2(randomized_red_fft, axes=(-2, -1))
    randomized_green_channel = np.fft.ifft2(randomized_green_fft, axes=(-2, -1))
    randomized_blue_channel = np.fft.ifft2(randomized_blue_fft, axes=(-2, -1))

    # Take the abs to get the image for each color channel
    randomized_red_channel = np.abs(randomized_red_channel)
    randomized_green_channel = np.abs(randomized_green_channel)
    randomized_blue_channel = np.abs(randomized_blue_channel)

    # Combine color channels into RGB tensor
    randomized_image = np.stack((randomized_red_channel, randomized_green_channel, randomized_blue_channel), axis=1)
    randomized_image_plot = torch.from_numpy(randomized_image)

    print(f'Norma: {torch.norm(image_tensor)}, \nNorma: {torch.norm(randomized_image_plot)}')

    return randomized_image_plot

# %%
def ifgsm_attack(input, epsilon, data_grad, control = True, mode ='flip'):
    iter = int(min([epsilon + 4, epsilon * 1.25]))  # Number of iterations

    alpha = 1
    pert_out = input.clone().detach()

    for i in range(iter):
        pert_out = pert_out + (alpha / 255) * data_grad.sign()

        if torch.norm((pert_out - input), p=float('inf')) > epsilon / 255:
            break

    adv_pert = (pert_out - input)
    adv_pert_max = torch.max(adv_pert)
    adv_pert_min = torch.min(adv_pert)
    adv_pert_plot = (adv_pert - adv_pert_min)/(adv_pert_max - adv_pert_min)
    normalization = torch.mean(pert_out - input)

    pert_out_plot = pert_out

    if control == True:
        if mode == 'flip':
                       
                control_pert_lr = torch.flip(adv_pert_plot, [3]) #left - right
                control_pert_tb = torch.flip(adv_pert_plot, [2]) #top - bottom
                transposed_image = adv_pert_plot.transpose(2, 3)
                control_pert_diag = torch.flip(transposed_image, [2, 3]) #diagonal

                mse_right_left = F.mse_loss(input, control_pert_lr).item()
                mse_top_bottom = F.mse_loss(input, control_pert_tb).item()
                mse_diagonal = F.mse_loss(input, control_pert_diag).item()

                mse_values = {"Top-bottom": mse_top_bottom, "Diagonal": mse_diagonal, "Right-left": mse_right_left}
                max_mse_flipped_type = max(mse_values, key=mse_values.get)
                print(mse_values)
                                
                if max_mse_flipped_type == "Top-bottom":
                    control_pert_plot = control_pert_tb
                    control_pert = torch.flip(adv_pert, [3])
                    print('Control: Top Bottom')
                    control_image = control_pert + input

                elif max_mse_flipped_type == "Diagonal":
                    control_pert_plot = control_pert_diag
                                        
                    transposed_image = adv_pert.transpose(2, 3)
                    control_pert = torch.flip(transposed_image, [2, 3])
                    print('Control: Diagonal')
                    control_image = control_pert + input

                else:
                    control_pert_plot = control_pert_lr
                    control_pert = torch.flip(adv_pert, [2])
                    print('Control: Left Right')
                    control_image = control_pert + input


        elif mode == 'rndm':
                control_pert_plot =  randomize_phase_torch(adv_pert_plot)
                control_image = control_pert_plot*epsilon/255 + input
                control_image = control_image.float()

                print(adv_pert)
                print(control_pert_plot)

        return pert_out_plot, adv_pert_plot, control_image, control_pert_plot 
    else:
        return pert_out_plot, adv_pert_plot

# %%
def ifgsm_attack_alternative(input, epsilon, data_grad, control = True, mode ='flip'):
    iter = 10  # Number of iterations

    alpha = epsilon/iter
    pert_out = input.clone().detach()

    for i in range(iter):
        pert_out = pert_out + (alpha / 255) * data_grad.sign()
        pert_out = torch.clamp(pert_out, 0, 1)
        eta = torch.clamp(pert_out - input, -epsilon/255, epsilon/255)
        pert_out = torch.clamp(input + eta, 0, 1)

    adv_pert = (pert_out - input)
    adv_pert_max = torch.max(adv_pert)
    adv_pert_min = torch.min(adv_pert)
    adv_pert_plot = (adv_pert - adv_pert_min)/(adv_pert_max - adv_pert_min)
    normalization = torch.mean(pert_out - input)

    pert_out_plot = pert_out

    if control == True:
        if mode == 'flip':
                       
                control_pert_lr = torch.flip(adv_pert_plot, [3]) #left - right
                control_pert_tb = torch.flip(adv_pert_plot, [2]) #top - bottom
                transposed_image = adv_pert_plot.transpose(2, 3)
                control_pert_diag = torch.flip(transposed_image, [2, 3]) #diagonal

                mse_right_left = F.mse_loss(input, control_pert_lr).item()
                mse_top_bottom = F.mse_loss(input, control_pert_tb).item()
                mse_diagonal = F.mse_loss(input, control_pert_diag).item()

                mse_values = {"Top-bottom": mse_top_bottom, "Diagonal": mse_diagonal, "Right-left": mse_right_left}
                max_mse_flipped_type = max(mse_values, key=mse_values.get)
                print(mse_values)
                                
                if max_mse_flipped_type == "Top-bottom":
                    control_pert_plot = control_pert_tb
                    control_pert = torch.flip(adv_pert, [3])
                    print('Control: Top Bottom')
                    control_image = control_pert + input

                elif max_mse_flipped_type == "Diagonal":
                    control_pert_plot = control_pert_diag
                                        
                    transposed_image = adv_pert.transpose(2, 3)
                    control_pert = torch.flip(transposed_image, [2, 3])
                    print('Control: Diagonal')
                    control_image = control_pert + input

                else:
                    control_pert_plot = control_pert_lr
                    control_pert = torch.flip(adv_pert, [2])
                    print('Control: Left Right')
                    control_image = control_pert + input


        elif mode == 'rndm':
                control_pert_plot =  randomize_phase_torch(adv_pert_plot)
                control_image = control_pert_plot*epsilon/255 + input
                control_image = control_image.float()

                print(adv_pert)
                print(control_pert_plot)
                
        return pert_out_plot, adv_pert_plot, control_image, control_pert_plot 
    else:
        return pert_out_plot, adv_pert_plot

# %%
def make_up_case(img, epsilon, models, weights, original_output, c_index, c_classes, output_dir):

    print('Generating Attack to Make the original output higher')
    transformed_image = weights(img).unsqueeze(0)
    original_image = transformed_image.clone()
    loss = nn.CrossEntropyLoss()
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    # Calculate ensemble predictions
    ensemble_outputs = []
    transformed_image.requires_grad = True
    for model in models:
        model.eval()
    output = model(normalize(transformed_image))
    ensemble_outputs.append(output)

    ensemble_outputs = torch.stack(ensemble_outputs)
    ensemble_mean_output = torch.mean(ensemble_outputs, dim=0)

    # Get original predictions
    original_output = ensemble_mean_output.clone()

    for model in models:
        model.eval()
    
    target = original_output.max(1)[1]   #maximize original output
    cost = -loss(original_output, target)

    for model in models:
        model.zero_grad()

    #loss.backward()
    grad = torch.autograd.grad(cost, transformed_image)[0]

    # Generate adversarial image
    perturbed_image, adv_pert = ifgsm_attack(transformed_image, epsilon, grad, control = False)

    perturbed_output = torch.mean(torch.stack([model(normalize(perturbed_image)) for model in models]), dim=0)
    perturbed_probs = torch.softmax(perturbed_output, dim=1)

    # Compute coarse category scores
    scores_perturbed = torch.zeros(size= (len(c_index),))

    for i in np.arange(len(c_index)): #Iterate in the coarse classes

        c = c_index[i] #coarse class indexs

        c_values_p = perturbed_probs[:, c]
        sum_p = torch.sum(c_values_p)
        scores_perturbed[i] = sum_p


    #Eliminate values of probs (perturbed and original)
    coarse_idx = np.hstack(c_index) #index to eliminate

    pert_coarse_scores = eliminate_elements_torch(perturbed_probs[0], coarse_idx)

    new_classes = [string for idx, string in enumerate(classes) if idx not in coarse_idx]

    #Concat new scores and new list of classes
    pert_coarse_scores = torch.cat((pert_coarse_scores,  scores_perturbed), dim = 0)

    new_classes = new_classes + c_classes

    sorted_probs_p, sorted_indices_p = torch.sort(pert_coarse_scores, descending=True)
    sorted_classes_p = [new_classes[i] for i in sorted_indices_p]

            
        # Sort predictions
    perturbed_top_classes = perturbed_probs[0].topk(1000)
    perturbed_dict = {classes[idx.item()]: prob.item() for idx, prob in zip(perturbed_top_classes.indices, perturbed_top_classes.values)}


    #sorting values 
    sorted_probs_p, sorted_indices_p = torch.sort(pert_coarse_scores, descending=True)
    sorted_classes_p = [new_classes[i] for i in sorted_indices_p]
        
    #define dicts with probs

    probs_p_scores = {}
    for key, value in zip(sorted_classes_p, sorted_probs_p):
        probs_p_scores[key] = value.item() 


    results = []
    results.append({'perturbed': perturbed_dict, 'pert_coarse_scores': probs_p_scores})

    counter = 1
    perturbed_image = perturbed_image.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
    perturbed_image = np.clip(perturbed_image, 0,1)
    perturbed_image = (perturbed_image * 255).astype('uint8')

    adv_pert = adv_pert.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
    adv_pert =  np.clip(adv_pert, 0, 1)
    adv_pert = (adv_pert * 255).astype('uint8')

    while True:
            # Generate folder name
        folder_name = f"images_folder_{counter}_epsilon_{epsilon}"
        folder_path = os.path.join(output_dir, folder_name)

        # Check if folder already exists
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
            break
        else:
            counter += 1
        

    atk_path = os.path.join(folder_path, 'atk.png')
    Image.fromarray(perturbed_image).resize((720,720)).save(atk_path)
    pert_path = os.path.join(folder_path, 'pert.png')
    Image.fromarray(adv_pert).resize((720,720)).save(pert_path)

    with gzip.open(os.path.join(folder_path, 'results.json.gz'), 'wt') as f:
                json.dump(results, f)

# %%
def attack(image_folder, models, weights, epsilon, classes, targeted = False, t = '0', coarse_class = 'nada', num_classes=1000, graph=False, folder=False, sorted = True,  attack = 'iFGSM',save_path = 0, make_upper = True, output_dir_up = '', control = True):
    """Test function to generate adversarial images and obtain predictions using an ensemble of models."""

    c_classes, c_index = get_coarse_arrays() 


    for model in models:
        model.eval()

    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    # Prepare output directory
    if folder:
        if save_path == 0:
            if targeted == False:
                output_dir = f"ensamble-attack_ensamble-c_epsilon-{epsilon}-untargeted"
            else:
                output_dir = f"ensamble-attack_ensamble-c_epsilon-{epsilon}-targeted"
            
            os.makedirs(output_dir, exist_ok=True)
        else:
            output_dir = save_path

    results = []
    control = []

    print('Iterating over images in folder\n\n')
    
    for i, image_name in enumerate(os.listdir(image_folder)):
        image_path = os.path.join(image_folder, image_name)
        print(f'\n\nImage {i + 1}/{len(os.listdir(image_folder))}--------------------------------------------------------\nImage name:{image_name}')

        # Load and transform image
        img = Image.open(image_path)
        transformed_image = weights(img).unsqueeze(0)
        original_image = transformed_image.clone()

        # Calculate ensemble predictions
        ensemble_outputs = []
        transformed_image.requires_grad = True
        for model in models:
            model.eval()
            try:
                output = model(normalize(transformed_image))
                ensemble_outputs.append(output)

            except RuntimeError as e:
                if "output with shape [1, 1, 256, 256] doesn't match the broadcast shape [1, 3, 256, 256]" in str(e):
                    print("Encountered specific RuntimeError. Moving to next element.")
                    continue

        ensemble_outputs = torch.stack(ensemble_outputs)
        ensemble_mean_output = torch.mean(ensemble_outputs, dim=0)

        # Get original predictions
        original_output = ensemble_mean_output.clone()
        original_probs = torch.softmax(original_output, dim=1)

        # Calculate loss
        loss = nn.CrossEntropyLoss()

        if targeted == True:
            if type(t) == str:
                target = original_output.max(1)[1]   #maximize original output
                cost = -loss(original_output, target)
            elif type(t) == int:
                target = torch.tensor([t])           #maximize target t
                cost = -loss(original_output, target)

            elif type(t) == np.ndarray or type(t) == list:
                w = extract_and_normalize(original_probs, t)
                probs_t = generate_list(1000, t, w)
                target = torch.tensor([probs_t])           
                cost = -loss(original_output, target)
        else:
            if type(t) != str:
                non_t = extract_values(np.arange(1000), t)
                w = extract_and_normalize(original_probs, non_t)
                probs_t = generate_list(1000, non_t, w)
                target = torch.tensor([probs_t])           
                cost = -loss(original_output, target)
            else:
                target = original_output.max(1)[1]
                cost = loss(original_output, target)  #minimize original output

        #Calculate grad
        for model in models:
            model.zero_grad()

        #loss.backward()
        grad = torch.autograd.grad(cost, transformed_image)[0]

        if control == True:
            perturbed_image, adv_pert, control_image, control_pert = ifgsm_attack_alternative(transformed_image, epsilon, grad, control = True)
        else:
            perturbed_image, adv_pert = ifgsm_attack_alternative(transformed_image, epsilon, grad, control = False)
        # Get perturbed predictions

        perturbed_output = torch.mean(torch.stack([model(normalize(perturbed_image)) for model in models]), dim=0)
        perturbed_probs = torch.softmax(perturbed_output, dim=1)

        if control == True:
            control_output = torch.mean(torch.stack([model(normalize(control_image)) for model in models]), dim=0)
            control_probs = torch.softmax(control_output, dim=1)


        # Compute coarse category scores
        #print('Fine Class --> Coarse class')

        scores_original = torch.zeros(size= (len(c_index),))
        scores_perturbed = torch.zeros(size= (len(c_index),))
        if control == True:
            scores_control = torch.zeros(size= (len(c_index),))

        for i in np.arange(len(c_index)): #Iterate in the coarse classes

            c = c_index[i] #coarse class indexs

            c_values = original_probs[:, c]
            sum = torch.sum(c_values)
            scores_original[i] = sum

            c_values_p = perturbed_probs[:, c]
            sum_p = torch.sum(c_values_p)
            scores_perturbed[i] = sum_p

            if control == True:
                c_values_c = control_probs[:, c]
                sum_c = torch.sum(c_values_c)
                scores_control[i] = sum_c

        #Eliminate values of probs (perturbed and original)
        coarse_idx = np.hstack(c_index) #index to eliminate
        coarse_scores = eliminate_elements_torch(original_probs[0], coarse_idx)
        pert_coarse_scores = eliminate_elements_torch(perturbed_probs[0], coarse_idx)
        if control == True:
            ctrl_coarse_scores = eliminate_elements_torch(control_probs[0], coarse_idx)

        new_classes = [string for idx, string in enumerate(classes) if idx not in coarse_idx]

        #Concat new scores and new list of classes
        coarse_scores = torch.cat((coarse_scores, scores_original), dim = 0)
        pert_coarse_scores = torch.cat((pert_coarse_scores,  scores_perturbed), dim = 0)
        if control == True:
            ctrl_coarse_scores = torch.cat((ctrl_coarse_scores,  scores_control), dim = 0)

        new_classes = new_classes + c_classes

        sorted_probs_p, sorted_indices_p = torch.sort(pert_coarse_scores, descending=True)
        sorted_classes_p = [new_classes[i] for i in sorted_indices_p]

        if folder:
            if type(t) != str:
                if len(t) > 1:
                    a = targeted == True
                    b = coarse_class != sorted_classes_p[0]
                    c = targeted == False
                    d = coarse_class == sorted_classes_p[0]
                    if  (a and b) or (c and d):
                        continue

            else:
                a = targeted == True
                b = t != sorted_classes_p[0]
                c = targeted == False
                d = t == sorted_classes_p[0]
                print(t, '----', sorted_classes_p[0])
                if  (a and b) or (c and d):
                    continue


        if make_upper == True:
            make_up_case(img, epsilon, models, weights, original_output, c_index, c_classes, output_dir_up)

        # Sort predictions
        original_top_classes = original_probs[0].topk(num_classes)
        perturbed_top_classes = perturbed_probs[0].topk(num_classes)
        if control == True:
            control_top_classes = control_probs[0].topk(num_classes)

        original_dict = {classes[idx.item()]: prob.item() for idx, prob in zip(original_top_classes.indices, original_top_classes.values)}
        perturbed_dict = {classes[idx.item()]: prob.item() for idx, prob in zip(perturbed_top_classes.indices, perturbed_top_classes.values)}
        if control == True:
            control_dict = {classes[idx.item()]: prob.item() for idx, prob in zip(control_top_classes.indices, control_top_classes.values)}

        #sorting values 
        sorted_probs, sorted_indices = torch.sort(coarse_scores, descending=True)
        sorted_classes = [new_classes[i] for i in sorted_indices]

        sorted_probs_p, sorted_indices_p = torch.sort(pert_coarse_scores, descending=True)
        sorted_classes_p = [new_classes[i] for i in sorted_indices_p]
        
        if control == True:
            sorted_probs_c, sorted_indices_c = torch.sort(ctrl_coarse_scores, descending=True)
            sorted_classes_c = [new_classes[i] for i in sorted_indices_c]

        #define dicts with probs
        probs_scores = {}
        for key, value in zip(sorted_classes, sorted_probs):
            probs_scores[key] = value.item() 

        probs_p_scores = {}
        for key, value in zip(sorted_classes_p, sorted_probs_p):
            probs_p_scores[key] = value.item() 

        if control == True:
            probs_c_scores = {}
            for key, value in zip(sorted_classes_c, sorted_probs_c):
                probs_c_scores[key] = value.item() 

        results.append({'original': original_dict, 'perturbed': perturbed_dict, 'coarse_scores': probs_scores, 'pert_coarse_scores': probs_p_scores})
        if control == True:
            control.append({'ctrl': control_dict, 'ctrl_scores': probs_c_scores})

        #print(probs_c_scores)

        # Save adversarial image
        if folder:
            counter = 1

            perturbed_image = perturbed_image.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
            perturbed_image = np.clip(perturbed_image, 0,1)
            perturbed_image = (perturbed_image * 255).astype('uint8')

            adv_pert = adv_pert.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
            adv_pert =  np.clip(adv_pert, 0, 1)
            adv_pert = (adv_pert * 255).astype('uint8')

            if control == True:
                control_image = control_image.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
                control_image = np.clip(control_image, 0, 1)
                control_image = (control_image * 255).astype('uint8')

                control_pert = control_pert.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
                control_pert = np.clip(control_pert, 0,1 )
                control_pert = (control_pert * 255).astype('uint8')

            while True:
                # Generate folder name
                folder_name = f"images_folder_{counter}_epsilon_{epsilon}"
                folder_path = os.path.join(output_dir, folder_name)

                # Check if folder already exists
                if not os.path.exists(folder_path):
                    os.makedirs(folder_path)
                    break
                else:
                    counter += 1
                    if counter > 165:
                        print(f'There are {165} images in the folder: MAX NUMBER REACHED.')
                        return

                

            atk_path = os.path.join(folder_path, 'atk.png')
            Image.fromarray(perturbed_image).resize((720,720)).save(atk_path)
            pert_path = os.path.join(folder_path, 'pert.png')
            Image.fromarray(adv_pert).resize((720,720)).save(pert_path)

            if control == True:
                control_pert_path = os.path.join(folder_path, 'control_pert.png')
                Image.fromarray(control_pert).resize((720,720)).save(control_pert_path, optimize=True)
                control_path = os.path.join(folder_path, 'control.png')
                Image.fromarray(control_image).resize((720,720)).save(control_path, optimize=True)

            with gzip.open(os.path.join(folder_path, 'results.json.gz'), 'wt') as f:
                json.dump(results, f)
                
            if control == True:
                with gzip.open(os.path.join(folder_path, 'control.json.gz'), 'wt') as f:
                    json.dump(control, f)

            if (a & b):
                print('SAVED IMAGE. Equal Target as Top Perturbed')
            elif (c & d):
                print('SAVED IMAGE. Different Top Perturbed from Original')


        print(f'Epsilon: {epsilon}')
        if targeted == True:
            if type(t) == str:
                print(f'Targeted Attack. Maximize Original Output\nOriginal prob: {probs_scores[sorted_classes[0]]},\nPerturbed prob: {probs_p_scores[sorted_classes[0]]}\nControl prob: {probs_c_scores[sorted_classes[0]]}')
            elif len(t) == 1:
                print(f'Targeted Attack = {classes[t[0]]}\nOriginal prob target: {probs_scores[classes[t[0]]]},\nPerturbed prob target: {probs_p_scores[classes[t[0]]]}\nControl prob target: {probs_c_scores[classes[t[0]]]}')
            elif len(t) > 1:
                print(f'Targeted Attack = {coarse_class}\nOriginal prob target: {probs_scores[coarse_class]},\nPerturbed prob target: {probs_p_scores[coarse_class]},\nPerturbed Top class & Prob: {sorted_classes_p[0]} & {sorted_probs_p[0]}')
                if control == True:
                    print(f'\nControl prob target: {probs_c_scores[coarse_class]}')
        else:
            print(f'Untargeted Attack. Minimize Original Output\nOriginal prob target: {probs_scores[sorted_classes[0]]},\nPerturbed prob target: {probs_p_scores[sorted_classes[0]]},\nPerturbed Top class & Prob: {sorted_classes_p[0]} & {sorted_probs_p[0]}')

        if graph:
            if folder != True:
                perturbed_image = perturbed_image.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
                adv_pert_plot = adv_pert.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
                if control == True:
                    control_image = control_image.squeeze().detach().cpu().numpy().transpose(1, 2, 0)
                control_pert = control_pert.squeeze().detach().cpu().numpy().transpose(1, 2, 0)

            f, axs = plt.subplots(1, 3, figsize=(17, 5))
            axs[0].imshow(original_image.squeeze().detach().cpu().numpy().transpose(1, 2, 0))
            axs[0].set_title(f"Original: {max(original_dict, key=original_dict.get)} - {np.round(max(original_dict.values()), 3)}" + "\n" + f"Original: {max(probs_scores, key=probs_scores.get)} - {np.round(max(probs_scores.values()), 3)}", fontsize=7)
            axs[0].set_axis_off()

            axs[1].imshow(np.clip(perturbed_image, 0, 1))
            axs[1].set_title(f"Perturbed: {max(perturbed_dict, key=perturbed_dict.get)} - {np.round(max(perturbed_dict.values()), 3)}" + "\n" + f"Perturbed: {max(probs_p_scores, key=probs_p_scores.get)} - {np.round(max(probs_p_scores.values()), 3)}", fontsize=7)
            axs[1].set_axis_off()

            axs[2].imshow(np.clip(control_image, 0, 1))
            axs[2].set_title(f"Control Image: {max(control_dict, key=control_dict.get)} - {np.round(max(control_dict.values()), 3)}" + "\n" + f"Control: {max(probs_c_scores, key=probs_c_scores.get)} - {np.round(max(probs_c_scores.values()), 3)}", fontsize=7)
            axs[2].set_axis_off() 

            plt.subplots_adjust(wspace=0.5)  # Add space between the plots
            plt.show()

            plt.subplot(1, 2, 1)
            plt.imshow(adv_pert_plot)
            plt.title(f"Perturbation", fontsize=7)
            plt.axis('off') 

            plt.subplot(1, 2, 2)
            plt.imshow(np.clip(control_pert, 0, 1))
            plt.title(f"Perturbation - Control", fontsize=7)
            plt.axis('off') 

            plt.subplots_adjust(wspace=0.5)  # Add space between the plots
            plt.show()

    return results

# %%
pizza_f = r'C:\Users\Usuario\Documents\Trini\Facultad\Tesis\Código Personal\image_net\class_images_image_net\00963'

# %%
classes[963]
# Out:
# 'pizza, pizza pie'

# %%
for eps in [16]:
    pizza_up = rf'C:\Users\Usuario\Documents\Trini\Facultad\Tesis\Código Personal\Results\Exp 2\Pizza\T up\Epsilon {eps}'
    pizza_down = rf'C:\Users\Usuario\Documents\Trini\Facultad\Tesis\Código Personal\Results\Exp 2\Pizza\T down\Epsilon {eps}'
    attack(pizza_f, models_, default_weights, eps, classes, targeted=False, t = classes[963], graph= False, folder = True, save_path=pizza_down, output_dir_up=pizza_up)
# Out:
# Iterating over images in folder
#
#
#
#
# Image 1/659--------------------------------------------------------
# Image name:000855800129055.jpg
# pizza, pizza pie ---- tray
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.5771474838256836,
# Perturbed prob target: 0.0038948131259530783,
# Perturbed Top class & Prob: tray & 0.279943585395813
#
#
# Image 2/659--------------------------------------------------------
# Image name:004181525192045.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 3/659--------------------------------------------------------
# Image name:004282416650661.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 4/659--------------------------------------------------------
# Image name:005860669879614.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 5/659--------------------------------------------------------
# Image name:007756893710414.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 6/659--------------------------------------------------------
# Image name:008289181895188.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9987956285476685,
# Perturbed prob target: 0.02353384532034397,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.912427544593811
#
#
# Image 7/659--------------------------------------------------------
# Image name:01004050744145.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9953147172927856,
# Perturbed prob target: 0.11581398546695709,
# Perturbed Top class & Prob: potpie & 0.15241794288158417
#
#
# Image 8/659--------------------------------------------------------
# Image name:01243474323092686.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 9/659--------------------------------------------------------
# Image name:01351869495743.jpg
# pizza, pizza pie ---- plate
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9622977375984192,
# Perturbed prob target: 0.0033734131138771772,
# Perturbed Top class & Prob: plate & 0.24829930067062378
#
#
# Image 10/659--------------------------------------------------------
# Image name:013879845458381057.jpg
# pizza, pizza pie ---- frying pan, frypan, skillet
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9951925277709961,
# Perturbed prob target: 0.296693354845047,
# Perturbed Top class & Prob: frying pan, frypan, skillet & 0.32061558961868286
#
#
# Image 11/659--------------------------------------------------------
# Image name:014937491531231.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 12/659--------------------------------------------------------
# Image name:0176783208493523.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 13/659--------------------------------------------------------
# Image name:019230706151207.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.6660881042480469,
# Perturbed prob target: 5.422970571089536e-05,
# Perturbed Top class & Prob: spaghetti squash & 0.767609715461731
#
#
# Image 14/659--------------------------------------------------------
# Image name:020479867015371.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9752106666564941,
# Perturbed prob target: 0.0025318071711808443,
# Perturbed Top class & Prob: potpie & 0.9718765020370483
#
#
# Image 15/659--------------------------------------------------------
# Image name:020548642740932.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 16/659--------------------------------------------------------
# Image name:0221714852654038.jpg
# pizza, pizza pie ---- Petri dish
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9656350612640381,
# Perturbed prob target: 0.007663934491574764,
# Perturbed Top class & Prob: Petri dish & 0.22660841047763824
#
#
# Image 17/659--------------------------------------------------------
# Image name:023625354430656.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8378933668136597,
# Perturbed prob target: 0.0012532315449789166,
# Perturbed Top class & Prob: acorn squash & 0.39315852522850037
#
#
# Image 18/659--------------------------------------------------------
# Image name:025769169267374.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9944565296173096,
# Perturbed prob target: 0.019306007772684097,
# Perturbed Top class & Prob: potpie & 0.9660477638244629
#
#
# Image 19/659--------------------------------------------------------
# Image name:026240371693997.jpg
# pizza, pizza pie ---- trifle
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9939348101615906,
# Perturbed prob target: 0.02320057339966297,
# Perturbed Top class & Prob: trifle & 0.9237052798271179
#
#
# Image 20/659--------------------------------------------------------
# Image name:026827099152292.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9781047701835632,
# Perturbed prob target: 0.009270189329981804,
# Perturbed Top class & Prob: spaghetti squash & 0.3712990880012512
#
#
# Image 21/659--------------------------------------------------------
# Image name:02737679632077.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 22/659--------------------------------------------------------
# Image name:029539374120798.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9945422410964966,
# Perturbed prob target: 0.010465135797858238,
# Perturbed Top class & Prob: potpie & 0.969531238079071
#
#
# Image 23/659--------------------------------------------------------
# Image name:0295503081300035.jpg
# pizza, pizza pie ---- bagel, beigel
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9909207820892334,
# Perturbed prob target: 0.22111131250858307,
# Perturbed Top class & Prob: bagel, beigel & 0.2284204363822937
#
#
# Image 24/659--------------------------------------------------------
# Image name:029764109523925.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8639878034591675,
# Perturbed prob target: 0.00019550517026800662,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.996787428855896
#
#
# Image 25/659--------------------------------------------------------
# Image name:029834969391815.jpg
# pizza, pizza pie ---- king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.924924373626709,
# Perturbed prob target: 0.002266504568979144,
# Perturbed Top class & Prob: king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica & 0.8029382228851318
#
#
# Image 26/659--------------------------------------------------------
# Image name:033641331905471.jpg
# pizza, pizza pie ---- pomegranate
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7843782901763916,
# Perturbed prob target: 0.0001326574565609917,
# Perturbed Top class & Prob: pomegranate & 0.8804901242256165
#
#
# Image 27/659--------------------------------------------------------
# Image name:035091070087144.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 28/659--------------------------------------------------------
# Image name:036955037263557.jpg
# pizza, pizza pie ---- isopod
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9293335676193237,
# Perturbed prob target: 0.004190152045339346,
# Perturbed Top class & Prob: isopod & 0.31703174114227295
#
#
# Image 29/659--------------------------------------------------------
# Image name:037749919379715.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 30/659--------------------------------------------------------
# Image name:038861471000087.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 31/659--------------------------------------------------------
# Image name:040362140400992.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9971662163734436,
# Perturbed prob target: 0.18677589297294617,
# Perturbed Top class & Prob: potpie & 0.597681999206543
#
#
# Image 32/659--------------------------------------------------------
# Image name:041979266058171.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 33/659--------------------------------------------------------
# Image name:043314689249664.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 34/659--------------------------------------------------------
# Image name:046070479381481455.jpg
# pizza, pizza pie ---- bagel, beigel
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.997593104839325,
# Perturbed prob target: 0.1441684365272522,
# Perturbed Top class & Prob: bagel, beigel & 0.49365684390068054
#
#
# Image 35/659--------------------------------------------------------
# Image name:0468161984176814.jpg
# pizza, pizza pie ---- butternut squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9947680234909058,
# Perturbed prob target: 0.005503779277205467,
# Perturbed Top class & Prob: butternut squash & 0.48452916741371155
#
#
# Image 36/659--------------------------------------------------------
# Image name:047415253323418.jpg
# pizza, pizza pie ---- pretzel
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9668448567390442,
# Perturbed prob target: 0.0020974650979042053,
# Perturbed Top class & Prob: pretzel & 0.38994938135147095
#
#
# Image 37/659--------------------------------------------------------
# Image name:047950441091548.jpg
# pizza, pizza pie ---- French loaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9677842855453491,
# Perturbed prob target: 0.007170039229094982,
# Perturbed Top class & Prob: French loaf & 0.2771599292755127
#
#
# Image 38/659--------------------------------------------------------
# Image name:0490663849318682.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 39/659--------------------------------------------------------
# Image name:0504773709510136.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 40/659--------------------------------------------------------
# Image name:050594508749872.jpg
# pizza, pizza pie ---- dog
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9284485578536987,
# Perturbed prob target: 0.03321515768766403,
# Perturbed Top class & Prob: dog & 0.06962142884731293
#
#
# Image 41/659--------------------------------------------------------
# Image name:051735803366512.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 42/659--------------------------------------------------------
# Image name:05174630042977.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 43/659--------------------------------------------------------
# Image name:051760236129025.jpg
# pizza, pizza pie ---- broccoli
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9550291299819946,
# Perturbed prob target: 0.009758311323821545,
# Perturbed Top class & Prob: broccoli & 0.73590087890625
#
#
# Image 44/659--------------------------------------------------------
# Image name:05398263595979.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 45/659--------------------------------------------------------
# Image name:0585632960850422.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9492030739784241,
# Perturbed prob target: 0.005498836282640696,
# Perturbed Top class & Prob: potpie & 0.900757908821106
#
#
# Image 46/659--------------------------------------------------------
# Image name:0626365382927139.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 47/659--------------------------------------------------------
# Image name:065948760231979.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 48/659--------------------------------------------------------
# Image name:067101680340965.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 49/659--------------------------------------------------------
# Image name:069712575037403.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9301632046699524,
# Perturbed prob target: 0.013538693077862263,
# Perturbed Top class & Prob: spaghetti squash & 0.3594453036785126
#
#
# Image 50/659--------------------------------------------------------
# Image name:072460925680548.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 51/659--------------------------------------------------------
# Image name:074636876827182.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 52/659--------------------------------------------------------
# Image name:076123325545147.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 53/659--------------------------------------------------------
# Image name:076867487060208.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9761587977409363,
# Perturbed prob target: 9.706861601443961e-05,
# Perturbed Top class & Prob: acorn squash & 0.9676454067230225
#
#
# Image 54/659--------------------------------------------------------
# Image name:077430522116159.jpg
# pizza, pizza pie ---- plate
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9936931133270264,
# Perturbed prob target: 0.18131156265735626,
# Perturbed Top class & Prob: plate & 0.3087243139743805
#
#
# Image 55/659--------------------------------------------------------
# Image name:07805018576298006.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8782199621200562,
# Perturbed prob target: 0.005418532062321901,
# Perturbed Top class & Prob: potpie & 0.6393368244171143
#
#
# Image 56/659--------------------------------------------------------
# Image name:0784495673603316.jpg
# pizza, pizza pie ---- butternut squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9031878113746643,
# Perturbed prob target: 0.003850125940516591,
# Perturbed Top class & Prob: butternut squash & 0.3099922835826874
#
#
# Image 57/659--------------------------------------------------------
# Image name:078513805423516.jpg
# pizza, pizza pie ---- carbonara
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9644840955734253,
# Perturbed prob target: 0.021696165204048157,
# Perturbed Top class & Prob: carbonara & 0.5458325743675232
#
#
# Image 58/659--------------------------------------------------------
# Image name:079508391723239.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 59/659--------------------------------------------------------
# Image name:079736244593209.jpg
# pizza, pizza pie ---- French loaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9918431639671326,
# Perturbed prob target: 0.06080818176269531,
# Perturbed Top class & Prob: French loaf & 0.42523038387298584
#
#
# Image 60/659--------------------------------------------------------
# Image name:081719608946627.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.931114912033081,
# Perturbed prob target: 0.00042506371391937137,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.9831719398498535
#
#
# Image 61/659--------------------------------------------------------
# Image name:082147285610936.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 62/659--------------------------------------------------------
# Image name:084345856654394.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 63/659--------------------------------------------------------
# Image name:084485739738117.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7017565369606018,
# Perturbed prob target: 0.00033699898631311953,
# Perturbed Top class & Prob: spaghetti squash & 0.5513064861297607
#
#
# Image 64/659--------------------------------------------------------
# Image name:085560040011837.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 65/659--------------------------------------------------------
# Image name:085827550218277.jpg
# pizza, pizza pie ---- burrito
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9917752742767334,
# Perturbed prob target: 0.1928762048482895,
# Perturbed Top class & Prob: burrito & 0.6390091776847839
#
#
# Image 66/659--------------------------------------------------------
# Image name:0870517361348426.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 67/659--------------------------------------------------------
# Image name:088221933828823.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9951691031455994,
# Perturbed prob target: 0.07918161898851395,
# Perturbed Top class & Prob: potpie & 0.6666479706764221
#
#
# Image 68/659--------------------------------------------------------
# Image name:0885745618283045.jpg
# pizza, pizza pie ---- Dutch oven
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9476251602172852,
# Perturbed prob target: 0.001669243793003261,
# Perturbed Top class & Prob: Dutch oven & 0.8368253111839294
#
#
# Image 69/659--------------------------------------------------------
# Image name:091928314286773.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9708160758018494,
# Perturbed prob target: 0.0005033269990235567,
# Perturbed Top class & Prob: acorn squash & 0.938578188419342
#
#
# Image 70/659--------------------------------------------------------
# Image name:092430582474476.jpg
# pizza, pizza pie ---- plate
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9886485934257507,
# Perturbed prob target: 0.025166096165776253,
# Perturbed Top class & Prob: plate & 0.48324090242385864
#
#
# Image 71/659--------------------------------------------------------
# Image name:096656435110558.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7869608402252197,
# Perturbed prob target: 0.0007429047836922109,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.8904802203178406
#
#
# Image 72/659--------------------------------------------------------
# Image name:098832753944363.jpg
# pizza, pizza pie ---- agaric
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9410452246665955,
# Perturbed prob target: 0.007685527205467224,
# Perturbed Top class & Prob: agaric & 0.4713524580001831
#
#
# Image 73/659--------------------------------------------------------
# Image name:0993408643757827.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 74/659--------------------------------------------------------
# Image name:101903586978905.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 75/659--------------------------------------------------------
# Image name:10347488901311097.jpg
# pizza, pizza pie ---- corn
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9555537700653076,
# Perturbed prob target: 0.02426774799823761,
# Perturbed Top class & Prob: corn & 0.6693847179412842
#
#
# Image 76/659--------------------------------------------------------
# Image name:1088856853375866.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9969700574874878,
# Perturbed prob target: 0.004407452419400215,
# Perturbed Top class & Prob: acorn squash & 0.3721376359462738
#
#
# Image 77/659--------------------------------------------------------
# Image name:109925366923312.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 78/659--------------------------------------------------------
# Image name:111320090975931.jpg
# pizza, pizza pie ---- frying pan, frypan, skillet
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9438483715057373,
# Perturbed prob target: 0.0028010201640427113,
# Perturbed Top class & Prob: frying pan, frypan, skillet & 0.633401095867157
#
#
# Image 79/659--------------------------------------------------------
# Image name:111501939275326.jpg
# pizza, pizza pie ---- Dutch oven
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8346582055091858,
# Perturbed prob target: 0.00012212785077281296,
# Perturbed Top class & Prob: Dutch oven & 0.7315351963043213
#
#
# Image 80/659--------------------------------------------------------
# Image name:111731179857878.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 81/659--------------------------------------------------------
# Image name:11245070582257877.jpg
# pizza, pizza pie ---- French loaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9666281938552856,
# Perturbed prob target: 0.013854149729013443,
# Perturbed Top class & Prob: French loaf & 0.46654775738716125
#
#
# Image 82/659--------------------------------------------------------
# Image name:11249831420848677.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 83/659--------------------------------------------------------
# Image name:11314086617303.jpg
# pizza, pizza pie ---- burrito
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.828773558139801,
# Perturbed prob target: 0.001703121466562152,
# Perturbed Top class & Prob: burrito & 0.8568580150604248
#
#
# Image 84/659--------------------------------------------------------
# Image name:114762027184874.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 85/659--------------------------------------------------------
# Image name:115846925532907.jpg
# pizza, pizza pie ---- brassiere, bra, bandeau
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.985582172870636,
# Perturbed prob target: 0.022941581904888153,
# Perturbed Top class & Prob: brassiere, bra, bandeau & 0.039277296513319016
#
#
# Image 86/659--------------------------------------------------------
# Image name:1168968071614582.jpg
# pizza, pizza pie ---- Dutch oven
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8834790587425232,
# Perturbed prob target: 0.00346828019246459,
# Perturbed Top class & Prob: Dutch oven & 0.5863226056098938
#
#
# Image 87/659--------------------------------------------------------
# Image name:1181295875123.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 88/659--------------------------------------------------------
# Image name:11873053604327999.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 89/659--------------------------------------------------------
# Image name:119638248217565.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 90/659--------------------------------------------------------
# Image name:1212543983640104.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 91/659--------------------------------------------------------
# Image name:124179453570996.jpg
# pizza, pizza pie ---- carton
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9171313643455505,
# Perturbed prob target: 0.0014291839906945825,
# Perturbed Top class & Prob: carton & 0.8434314131736755
#
#
# Image 92/659--------------------------------------------------------
# Image name:125050348247223.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 93/659--------------------------------------------------------
# Image name:1261705108227165.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 94/659--------------------------------------------------------
# Image name:126618318426809.jpg
# pizza, pizza pie ---- hotdog, hot dog, red hot
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7460433840751648,
# Perturbed prob target: 0.0002901366678997874,
# Perturbed Top class & Prob: hotdog, hot dog, red hot & 0.9280483722686768
#
#
# Image 95/659--------------------------------------------------------
# Image name:126772739861515.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 96/659--------------------------------------------------------
# Image name:127463466025583.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8739528656005859,
# Perturbed prob target: 3.856926196021959e-05,
# Perturbed Top class & Prob: acorn squash & 0.9967091083526611
#
#
# Image 97/659--------------------------------------------------------
# Image name:128177407572972.jpg
# pizza, pizza pie ---- carbonara
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7133858799934387,
# Perturbed prob target: 4.6865083277225494e-05,
# Perturbed Top class & Prob: carbonara & 0.9978044629096985
#
#
# Image 98/659--------------------------------------------------------
# Image name:1329300376833074.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 99/659--------------------------------------------------------
# Image name:1340681913057864.jpg
# pizza, pizza pie ---- plastic bag
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9318382143974304,
# Perturbed prob target: 0.0019024424254894257,
# Perturbed Top class & Prob: plastic bag & 0.3978143334388733
#
#
# Image 100/659--------------------------------------------------------
# Image name:136578320509823.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 101/659--------------------------------------------------------
# Image name:1373605597978562.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 102/659--------------------------------------------------------
# Image name:140042974291972.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 103/659--------------------------------------------------------
# Image name:141947075564005.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 104/659--------------------------------------------------------
# Image name:144482433364093.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 105/659--------------------------------------------------------
# Image name:145767123113152.jpg
# pizza, pizza pie ---- trifle
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9880645871162415,
# Perturbed prob target: 0.005136358086019754,
# Perturbed Top class & Prob: trifle & 0.9789944291114807
#
#
# Image 106/659--------------------------------------------------------
# Image name:145871734206108.jpg
# pizza, pizza pie ---- carbonara
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7772594690322876,
# Perturbed prob target: 0.0010519989300519228,
# Perturbed Top class & Prob: carbonara & 0.6063653230667114
#
#
# Image 107/659--------------------------------------------------------
# Image name:146393794983422.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9588153958320618,
# Perturbed prob target: 0.004649490118026733,
# Perturbed Top class & Prob: spaghetti squash & 0.26120907068252563
#
#
# Image 108/659--------------------------------------------------------
# Image name:148117539317758.jpg
# pizza, pizza pie ---- corn
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9976744055747986,
# Perturbed prob target: 0.05107749253511429,
# Perturbed Top class & Prob: corn & 0.8351306915283203
#
#
# Image 109/659--------------------------------------------------------
# Image name:151742738261415.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 110/659--------------------------------------------------------
# Image name:15309604561001.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.5582777857780457,
# Perturbed prob target: 9.720026719151065e-05,
# Perturbed Top class & Prob: potpie & 0.9994175434112549
#
#
# Image 111/659--------------------------------------------------------
# Image name:154339140549193.jpg
# pizza, pizza pie ---- plate
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9400489926338196,
# Perturbed prob target: 0.037404078990221024,
# Perturbed Top class & Prob: plate & 0.1506216824054718
#
#
# Image 112/659--------------------------------------------------------
# Image name:1554009469422042.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 113/659--------------------------------------------------------
# Image name:155759821191726.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 114/659--------------------------------------------------------
# Image name:1568637672213211.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 115/659--------------------------------------------------------
# Image name:1572418387544856.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9867760539054871,
# Perturbed prob target: 0.02589959278702736,
# Perturbed Top class & Prob: potpie & 0.9510906338691711
#
#
# Image 116/659--------------------------------------------------------
# Image name:160308632420935.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9540634751319885,
# Perturbed prob target: 0.05365057662129402,
# Perturbed Top class & Prob: potpie & 0.4950006604194641
#
#
# Image 117/659--------------------------------------------------------
# Image name:1626006076770297.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 118/659--------------------------------------------------------
# Image name:16410451112611746.jpg
# pizza, pizza pie ---- wooden spoon
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.23881934583187103,
# Perturbed prob target: 1.716075712465681e-05,
# Perturbed Top class & Prob: wooden spoon & 0.8024947047233582
#
#
# Image 119/659--------------------------------------------------------
# Image name:16467668873787.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 120/659--------------------------------------------------------
# Image name:166808022335479.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 121/659--------------------------------------------------------
# Image name:1670722229114465.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 122/659--------------------------------------------------------
# Image name:16820465035454.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 123/659--------------------------------------------------------
# Image name:168590788108215.jpg
# pizza, pizza pie ---- French loaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9600714445114136,
# Perturbed prob target: 0.01469813659787178,
# Perturbed Top class & Prob: French loaf & 0.58721524477005
#
#
# Image 124/659--------------------------------------------------------
# Image name:1686875154915717.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9762716293334961,
# Perturbed prob target: 0.004877894651144743,
# Perturbed Top class & Prob: potpie & 0.4156950116157532
#
#
# Image 125/659--------------------------------------------------------
# Image name:16929808764215903.jpg
# pizza, pizza pie ---- burrito
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9869065284729004,
# Perturbed prob target: 0.005792958661913872,
# Perturbed Top class & Prob: burrito & 0.8761491775512695
#
#
# Image 126/659--------------------------------------------------------
# Image name:1694785318722973.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 127/659--------------------------------------------------------
# Image name:1710323345735325.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8430222868919373,
# Perturbed prob target: 0.00044309202348813415,
# Perturbed Top class & Prob: acorn squash & 0.4539729654788971
#
#
# Image 128/659--------------------------------------------------------
# Image name:172689374766076.jpg
# pizza, pizza pie ---- hot pot, hotpot
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9755510091781616,
# Perturbed prob target: 0.018140146508812904,
# Perturbed Top class & Prob: hot pot, hotpot & 0.3189861476421356
#
#
# Image 129/659--------------------------------------------------------
# Image name:177088605796395.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 130/659--------------------------------------------------------
# Image name:1781666465740082.jpg
# pizza, pizza pie ---- bagel, beigel
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9331186413764954,
# Perturbed prob target: 0.0006076080608181655,
# Perturbed Top class & Prob: bagel, beigel & 0.9449512362480164
#
#
# Image 131/659--------------------------------------------------------
# Image name:179236405580933.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 132/659--------------------------------------------------------
# Image name:18080948021801.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 133/659--------------------------------------------------------
# Image name:182358639661369.jpg
# pizza, pizza pie ---- trifle
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9955779314041138,
# Perturbed prob target: 0.3033038377761841,
# Perturbed Top class & Prob: trifle & 0.582264244556427
#
#
# Image 134/659--------------------------------------------------------
# Image name:1841864720452133.jpg
# pizza, pizza pie ---- frying pan, frypan, skillet
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9981995820999146,
# Perturbed prob target: 0.046728432178497314,
# Perturbed Top class & Prob: frying pan, frypan, skillet & 0.8618513941764832
#
#
# Image 135/659--------------------------------------------------------
# Image name:189203522067495.jpg
# pizza, pizza pie ---- frying pan, frypan, skillet
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9826410412788391,
# Perturbed prob target: 0.011477990075945854,
# Perturbed Top class & Prob: frying pan, frypan, skillet & 0.5414809584617615
#
#
# Image 136/659--------------------------------------------------------
# Image name:192038622826373.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 137/659--------------------------------------------------------
# Image name:192967984786881.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9808382391929626,
# Perturbed prob target: 0.011038423515856266,
# Perturbed Top class & Prob: potpie & 0.9317744374275208
#
#
# Image 138/659--------------------------------------------------------
# Image name:1933283546907.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9920439124107361,
# Perturbed prob target: 0.009633318521082401,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.8269922733306885
#
#
# Image 139/659--------------------------------------------------------
# Image name:195531078065293.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 140/659--------------------------------------------------------
# Image name:196633776991215.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 141/659--------------------------------------------------------
# Image name:199693352728912.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 142/659--------------------------------------------------------
# Image name:19980099990327.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 143/659--------------------------------------------------------
# Image name:20062748374697126.jpg
# pizza, pizza pie ---- bagel, beigel
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9959158301353455,
# Perturbed prob target: 0.007988537661731243,
# Perturbed Top class & Prob: bagel, beigel & 0.9103872179985046
#
#
# Image 144/659--------------------------------------------------------
# Image name:202408063062645.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 145/659--------------------------------------------------------
# Image name:2035311965860145.jpg
# pizza, pizza pie ---- burrito
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9391843676567078,
# Perturbed prob target: 0.0003654497559182346,
# Perturbed Top class & Prob: burrito & 0.9936461448669434
#
#
# Image 146/659--------------------------------------------------------
# Image name:2050256964933.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 147/659--------------------------------------------------------
# Image name:206153432197855.jpg
# pizza, pizza pie ---- acorn squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9905166029930115,
# Perturbed prob target: 0.006414908450096846,
# Perturbed Top class & Prob: acorn squash & 0.5549875497817993
#
#
# Image 148/659--------------------------------------------------------
# Image name:207099774826777.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 149/659--------------------------------------------------------
# Image name:208444669091326.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 150/659--------------------------------------------------------
# Image name:20850111508070368.jpg
# pizza, pizza pie ---- French loaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9415959715843201,
# Perturbed prob target: 0.006226842757314444,
# Perturbed Top class & Prob: French loaf & 0.10394710302352905
#
#
# Image 151/659--------------------------------------------------------
# Image name:2131437023068481.jpg
# pizza, pizza pie ---- cucumber, cuke
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9574289917945862,
# Perturbed prob target: 0.004448486026376486,
# Perturbed Top class & Prob: cucumber, cuke & 0.3585929870605469
#
#
# Image 152/659--------------------------------------------------------
# Image name:2135250841034582.jpg
# pizza, pizza pie ---- mashed potato
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9697721004486084,
# Perturbed prob target: 0.11600863933563232,
# Perturbed Top class & Prob: mashed potato & 0.38395941257476807
#
#
# Image 153/659--------------------------------------------------------
# Image name:2137988325523175.jpg
# pizza, pizza pie ---- spatula
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.96976637840271,
# Perturbed prob target: 0.06185609847307205,
# Perturbed Top class & Prob: spatula & 0.2025192528963089
#
#
# Image 154/659--------------------------------------------------------
# Image name:213935342485249.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 155/659--------------------------------------------------------
# Image name:215080547981279.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9604328870773315,
# Perturbed prob target: 0.0036633394192904234,
# Perturbed Top class & Prob: potpie & 0.5965632796287537
#
#
# Image 156/659--------------------------------------------------------
# Image name:216029879795982.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9110698103904724,
# Perturbed prob target: 0.06280742585659027,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.2203814685344696
#
#
# Image 157/659--------------------------------------------------------
# Image name:221258111348797.jpg
# pizza, pizza pie ---- corn
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8306165933609009,
# Perturbed prob target: 9.93831708910875e-05,
# Perturbed Top class & Prob: corn & 0.9146758317947388
#
#
# Image 158/659--------------------------------------------------------
# Image name:2224664854242997.jpg
# pizza, pizza pie ---- corn
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.7797505855560303,
# Perturbed prob target: 0.0035472307354211807,
# Perturbed Top class & Prob: corn & 0.5781736969947815
#
#
# Image 159/659--------------------------------------------------------
# Image name:227689787899607.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9920269846916199,
# Perturbed prob target: 0.07984670996665955,
# Perturbed Top class & Prob: potpie & 0.8344247341156006
#
#
# Image 160/659--------------------------------------------------------
# Image name:228428680986282.jpg
# pizza, pizza pie ---- French loaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9205244779586792,
# Perturbed prob target: 0.025815889239311218,
# Perturbed Top class & Prob: French loaf & 0.13633441925048828
#
#
# Image 161/659--------------------------------------------------------
# Image name:2286543586452743.jpg
# pizza, pizza pie ---- guacamole
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9603808522224426,
# Perturbed prob target: 0.0003012903325725347,
# Perturbed Top class & Prob: guacamole & 0.9295397400856018
#
#
# Image 162/659--------------------------------------------------------
# Image name:22890237591411844.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 163/659--------------------------------------------------------
# Image name:231681022633501.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9141519069671631,
# Perturbed prob target: 0.00017519894754514098,
# Perturbed Top class & Prob: spaghetti squash & 0.9446905255317688
#
#
# Image 164/659--------------------------------------------------------
# Image name:232043260815945.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 165/659--------------------------------------------------------
# Image name:234858979220351.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 166/659--------------------------------------------------------
# Image name:2400342168621574.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 167/659--------------------------------------------------------
# Image name:24151844698675.jpg
# pizza, pizza pie ---- meat loaf, meatloaf
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9966086149215698,
# Perturbed prob target: 0.20620425045490265,
# Perturbed Top class & Prob: meat loaf, meatloaf & 0.23967859148979187
#
#
# Image 168/659--------------------------------------------------------
# Image name:243090153566374.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 169/659--------------------------------------------------------
# Image name:2463730913074365.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 170/659--------------------------------------------------------
# Image name:2469765090819855.jpg
# pizza, pizza pie ---- spaghetti squash
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9896088242530823,
# Perturbed prob target: 0.050502002239227295,
# Perturbed Top class & Prob: spaghetti squash & 0.3346739411354065
#
#
# Image 171/659--------------------------------------------------------
# Image name:247055250567076.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 172/659--------------------------------------------------------
# Image name:247648697720359.jpg
# pizza, pizza pie ---- confectionery, confectionary, candy store
# Generating Attack to Make the original output higher
# Epsilon: 2
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.3437521457672119,
# Perturbed prob target: 0.00017834290338214487,
# Perturbed Top class & Prob: confectionery, confectionary, candy store & 0.5812963247299194
#
#
# ...
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 178/659--------------------------------------------------------
# Image name:2649671603819517.jpg
# pizza, pizza pie ---- guacamole
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9610912203788757,
# Perturbed prob target: 0.0013501396169885993,
# Perturbed Top class & Prob: guacamole & 0.18736718595027924
#
#
# Image 179/659--------------------------------------------------------
# Image name:2668629013245647.jpg
# pizza, pizza pie ---- confectionery, confectionary, candy store
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9402357935905457,
# Perturbed prob target: 0.010083028115332127,
# Perturbed Top class & Prob: confectionery, confectionary, candy store & 0.21978500485420227
#
#
# Image 180/659--------------------------------------------------------
# Image name:268347269103635.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 181/659--------------------------------------------------------
# Image name:2703702790586244.jpg
# pizza, pizza pie ---- caldron, cauldron
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9869411587715149,
# Perturbed prob target: 0.0143708735704422,
# Perturbed Top class & Prob: caldron, cauldron & 0.06779104471206665
#
#
# Image 182/659--------------------------------------------------------
# Image name:27038436952994904.jpg
# pizza, pizza pie ---- broccoli
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9905561804771423,
# Perturbed prob target: 0.02222047559916973,
# Perturbed Top class & Prob: broccoli & 0.4209938943386078
#
#
# Image 183/659--------------------------------------------------------
# Image name:270848884952671.jpg
# pizza, pizza pie ---- crayfish, crawfish, crawdad, crawdaddy
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9761369824409485,
# Perturbed prob target: 0.002881737193092704,
# Perturbed Top class & Prob: crayfish, crawfish, crawdad, crawdaddy & 0.752816915512085
#
#
# Image 184/659--------------------------------------------------------
# Image name:272751119722054.jpg
# pizza, pizza pie ---- guacamole
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9846405982971191,
# Perturbed prob target: 0.10116861760616302,
# Perturbed Top class & Prob: guacamole & 0.15601962804794312
#
#
# Image 185/659--------------------------------------------------------
# Image name:2727813616312496.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 186/659--------------------------------------------------------
# Image name:272810986136349.jpg
# pizza, pizza pie ---- potpie
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9983273148536682,
# Perturbed prob target: 0.19294726848602295,
# Perturbed Top class & Prob: potpie & 0.7291273474693298
#
#
# Image 187/659--------------------------------------------------------
# Image name:272901401765014.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 188/659--------------------------------------------------------
# Image name:2739263646217496.jpg
# pizza, pizza pie ---- corn
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9696897864341736,
# Perturbed prob target: 0.0016146732959896326,
# Perturbed Top class & Prob: corn & 0.35103121399879456
#
#
# Image 189/659--------------------------------------------------------
# Image name:2739532129977365.jpg
# pizza, pizza pie ---- broccoli
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9508745074272156,
# Perturbed prob target: 0.0016526198014616966,
# Perturbed Top class & Prob: broccoli & 0.9750932455062866
#
#
# Image 190/659--------------------------------------------------------
# Image name:274590217833957.jpg
# pizza, pizza pie ---- pizza, pizza pie
#
#
# Image 191/659--------------------------------------------------------
# Image name:275931591291813.jpg
# pizza, pizza pie ---- bagel, beigel
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.9944981932640076,
# Perturbed prob target: 0.005622401833534241,
# Perturbed Top class & Prob: bagel, beigel & 0.5925869345664978
#
#
# Image 192/659--------------------------------------------------------
# Image name:278201407618201.jpg
# pizza, pizza pie ---- king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.981964111328125,
# Perturbed prob target: 0.007762593682855368,
# Perturbed Top class & Prob: king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica & 0.30188673734664917
#
#
# Image 193/659--------------------------------------------------------
# Image name:2783830976538844.jpg
# pizza, pizza pie ---- bakery, bakeshop, bakehouse
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.6218680143356323,
# Perturbed prob target: 0.0003898300928995013,
# Perturbed Top class & Prob: bakery, bakeshop, bakehouse & 0.6612890958786011
#
#
# Image 194/659--------------------------------------------------------
# Image name:281501548738149.jpg
# pizza, pizza pie ---- plate
# Generating Attack to Make the original output higher
# Epsilon: 8
# Untargeted Attack. Minimize Original Output
# Original prob target: 0.8491135239601135,
# Perturbed prob target: 0.0017991417553275824,
# Perturbed Top class & Prob: plate & 0.4003129303455353
#
#
# Image 195/659--------------------------------------------------------
# Image name:283086705836263.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 4
#       2 pizza_up = rf'C:\Users\Usuario\Documents\Trini\Facultad\Tesis\Código Personal\Results\Exp 2\Pizza\T up\Epsilon {eps}'
#       3 pizza_down = rf'C:\Users\Usuario\Documents\Trini\Facultad\Tesis\Código Personal\Results\Exp 2\Pizza\T down\Epsilon {eps}'
# ----> 4 attack(pizza_f, models_, default_weights, eps, classes, targeted=False, t = classes[963], graph= False, folder = True, save_path=pizza_down, output_dir_up=pizza_up)
#
# Cell In[31], line 44, in attack(image_folder, models, weights, epsilon, classes, targeted, t, coarse_class, num_classes, graph, folder, sorted, attack, save_path, make_upper, output_dir_up, control)
#      42 model.eval()
#      43 try:
# ---> 44     output = model(normalize(transformed_image))
#      45     ensemble_outputs.append(output)
#      47 except RuntimeError as e:
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torchvision\models\efficientnet.py:343, in EfficientNet.forward(self, x)
#     342 def forward(self, x: Tensor) -> Tensor:
# --> 343     return self._forward_impl(x)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torchvision\models\efficientnet.py:333, in EfficientNet._forward_impl(self, x)
#     332 def _forward_impl(self, x: Tensor) -> Tensor:
# --> 333     x = self.features(x)
#     335     x = self.avgpool(x)
#     336     x = torch.flatten(x, 1)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torchvision\models\efficientnet.py:164, in MBConv.forward(self, input)
#     163 def forward(self, input: Tensor) -> Tensor:
# --> 164     result = self.block(input)
#     165     if self.use_res_connect:
#     166         result = self.stochastic_depth(result)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\modules\activation.py:393, in SiLU.forward(self, input)
#     392 def forward(self, input: Tensor) -> Tensor:
# --> 393     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\Usuario\anaconda3\envs\pytorch_env\Lib\site-packages\torch\nn\functional.py:2074, in silu(input, inplace)
#    2072     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2073 if inplace:
# -> 2074     return torch._C._nn.silu_(input)
#    2075 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
